# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\airquality.csv", sep=',')

# %%
df.head(10)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5
# 5           6   28.0      NaN  14.9    66      5    6
# 6           7   23.0    299.0   8.6    65      5    7
# 7           8   19.0     99.0  13.8    59      5    8
# 8           9    8.0     19.0  20.1    61      5    9
# 9          10    NaN    194.0   8.6    69      5   10

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %% [markdown]
# # data cleaning

# %%
df1 = df.drop('Unnamed: 0', axis =1)
df1
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 148   30.0    193.0   6.9    70      9   26
# 149    NaN    145.0  13.2    77      9   27
# 150   14.0    191.0  14.3    75      9   28
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %% [markdown]
# # replacing numerical null values

# %%
df1['Ozone'] = df1['Ozone'].fillna(df1['Ozone'].mean())
df1['Solar.R'] = df1['Solar.R'].fillna(df1['Solar.R'].mean())
df1
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day
# 0    41.00000  190.000000   7.4    67      5    1
# 1    36.00000  118.000000   8.0    72      5    2
# 2    12.00000  149.000000  12.6    74      5    3
# 3    18.00000  313.000000  11.5    62      5    4
# 4    42.12931  185.931507  14.3    56      5    5
# ..        ...         ...   ...   ...    ...  ...
# 148  30.00000  193.000000   6.9    70      9   26
# 149  42.12931  145.000000  13.2    77      9   27
# 150  14.00000  191.000000  14.3    75      9   28
# 151  18.00000  131.000000   8.0    76      9   29
# 152  20.00000  223.000000  11.5    68      9   30
#
# [153 rows x 6 columns]

# %%
df1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
df1.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp         int64
# Month        int64
# Day          int64
# dtype: object

# %% [markdown]
# # data transformation

# %%
from sklearn.preprocessing import LabelEncoder
S = LabelEncoder()
df1['Humidity'] = S.fit_transform(df1['Humidity'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python37\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python37\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python37\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Humidity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
# ...

# %% [markdown]
# # data integration

# %%
#creating subsets
s1 = df1[['Ozone', 'Solar.R', 'Wind','Temp', 'Month','Day']].loc[0:15]
s1
# Out:
#        Ozone     Solar.R  Wind  Temp  Month  Day
# 0   41.00000  190.000000   7.4    67      5    1
# 1   36.00000  118.000000   8.0    72      5    2
# 2   12.00000  149.000000  12.6    74      5    3
# 3   18.00000  313.000000  11.5    62      5    4
# 4   42.12931  185.931507  14.3    56      5    5
# 5   28.00000  185.931507  14.9    66      5    6
# 6   23.00000  299.000000   8.6    65      5    7
# 7   19.00000   99.000000  13.8    59      5    8
# 8    8.00000   19.000000  20.1    61      5    9
# 9   42.12931  194.000000   8.6    69      5   10
# 10   7.00000  185.931507   6.9    74      5   11
# 11  16.00000  256.000000   9.7    69      5   12
# 12  11.00000  290.000000   9.2    66      5   13
# 13  14.00000  274.000000  10.9    68      5   14
# 14  18.00000   65.000000  13.2    58      5   15
# 15  14.00000  334.000000  11.5    64      5   16

# %%
s2 = df1[['Ozone', 'Solar.R', 'Wind','Temp', 'Month','Day']].loc[16:30]
s2
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day
# 16   34.00000  307.000000  12.0    66      5   17
# 17    6.00000   78.000000  18.4    57      5   18
# 18   30.00000  322.000000  11.5    68      5   19
# 19   11.00000   44.000000   9.7    62      5   20
# 20    1.00000    8.000000   9.7    59      5   21
# 21   11.00000  320.000000  16.6    73      5   22
# 22    4.00000   25.000000   9.7    61      5   23
# 23   32.00000   92.000000  12.0    61      5   24
# 24   42.12931   66.000000  16.6    57      5   25
# 25   42.12931  266.000000  14.9    58      5   26
# 26   42.12931  185.931507   8.0    57      5   27
# 27   23.00000   13.000000  12.0    67      5   28
# 28   45.00000  252.000000  14.9    81      5   29
# 29  115.00000  223.000000   5.7    79      5   30
# 30   37.00000  279.000000   7.4    76      5   31

# %%
#merge subsets
merge = pd.concat([s1, s2])
merge
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day
# 0    41.00000  190.000000   7.4    67      5    1
# 1    36.00000  118.000000   8.0    72      5    2
# 2    12.00000  149.000000  12.6    74      5    3
# 3    18.00000  313.000000  11.5    62      5    4
# 4    42.12931  185.931507  14.3    56      5    5
# 5    28.00000  185.931507  14.9    66      5    6
# 6    23.00000  299.000000   8.6    65      5    7
# 7    19.00000   99.000000  13.8    59      5    8
# 8     8.00000   19.000000  20.1    61      5    9
# 9    42.12931  194.000000   8.6    69      5   10
# 10    7.00000  185.931507   6.9    74      5   11
# 11   16.00000  256.000000   9.7    69      5   12
# 12   11.00000  290.000000   9.2    66      5   13
# 13   14.00000  274.000000  10.9    68      5   14
# 14   18.00000   65.000000  13.2    58      5   15
# 15   14.00000  334.000000  11.5    64      5   16
# 16   34.00000  307.000000  12.0    66      5   17
# 17    6.00000   78.000000  18.4    57      5   18
# ...

# %% [markdown]
# # plotting heatmap

# %%
co = df1.corr()
co
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.302970 -0.530936  0.608742  0.149081 -0.011355
# Solar.R  0.302970  1.000000 -0.055245  0.262569 -0.072904 -0.145621
# Wind    -0.530936 -0.055245  1.000000 -0.457988 -0.178293  0.027181
# Temp     0.608742  0.262569 -0.457988  1.000000  0.420947 -0.130593
# Month    0.149081 -0.072904 -0.178293  0.420947  1.000000 -0.007962
# Day     -0.011355 -0.145621  0.027181 -0.130593 -0.007962  1.000000

# %%
import seaborn as sns
sns.heatmap(co, vmin = -1, vmax = 1, annot = True)
# Out:
# <Axes: >

# %%
# !pip install seaborn

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # model creation

# %%
x = df1[["Ozone"]]
y = df1[["Temp"]]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypredict = model.predict(xtest)

# %% [markdown]
# # plotting graph

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(xtrain, ytrain, color = "red")
plt.scatter(ytest, ypredict, color = "blue")
plt.legend(["Ozone"])
plt.xlabel("Ozone")
plt.ylabel("Temp")
plt.title("Ozone Vs Temp")
plt.show()

# %% [markdown]
# # metrics calculation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
MSE = mean_squared_error(ytest, ypredict)
MAE = mean_absolute_error(ytest, ypredict)
r2_score = r2_score(ytest, ypredict)
RMSE = np.sqrt(MSE)

# %%
print("MSE : {}\nRMSE : {} \nMAE : {} \nR2 SCORE : {}".format(MSE, RMSE, MAE, r2_score))
# Out:
# MSE : 49.41007957574915
# RMSE : 7.029230368664066
# MAE : 5.425390004111956
# R2 SCORE : 0.30905552119707036
